# %% [markdown]
# #### Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.
# ##### Pearson Correlation Coefficien
#
# The Pearson correlation coefficient ($ r $) measures the linear relationship between two variables. The formula for Pearson correlation is:
#
# $ r = \frac{\sum (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum (x_i - \bar{x})^2 \sum (y_i - \bar{y})^2}} $
#
# where $ x_i $ and $ y_i $ are individual data points, and $ \bar{x} $ and $ \bar{y} $ are the means of the $ x $ and $ y $ variables, respectively.
#
# **Interpretation:**
#
# - $ r $ ranges from -1 to 1.
# - $ r = 1 $ indicates a perfect positive linear relationship.
# - $ r = -1 $ indicates a perfect negative linear relationship.
# - $ r = 0 $ indicates no linear relationship.
#
# #### Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.
# ##### Spearman's Rank Correlation
#
# Spearman's rank correlation ($ \rho $) measures the monotonic relationship between two variables. To calculate Spearman's rank correlation:
#
# 1. Rank each variable separately.
# 2. Compute the difference $ d_i $ between ranks for each pair of variables.
# 3. Use the formula:
#
# $ \rho = 1 - \frac{6 \sum d_i^2}{n(n^2 - 1)} $
#
# where $ d_i $ is the difference between ranks for each pair, and $ n $ is the number of data points.
#
# **Interpretation:**
#
# - $ \rho $ ranges from -1 to 1.
# - $ \rho = 1 $ indicates a perfect positive monotonic relationship.
# - $ \rho = -1 $ indicates a perfect negative monotonic relationship.
# - $ \rho = 0 $ indicates no monotonic relationship.
#
#
# #### Q3. Suppose you are conducting a study to examine the relationship between the number of hours ofexercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.
# ##### Pearson vs. Spearman for Exercise and BMI
#
# Calculate both Pearson and Spearman correlations using the formulas provided in Q1 and Q2.
#
# - **Pearson Correlation:** Measures the linear relationship between hours of exercise and BMI.
# - **Spearman Correlation:** Measures the monotonic relationship between hours of exercise and BMI.
#
# **Comparison:**
#
# - If Pearson and Spearman values are similar, the relationship is likely both linear and monotonic.
# - If they differ significantly, the relationship might be monotonic but not linear, or vice versa.
#
# #### Q4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between these two variables.
# ##### Pearson Correlation for TV Hours and Physical Activity
#
# Use the Pearson correlation formula to assess the linear relationship between hours spent watching television and level of physical activity.
#
# **Interpretation:**
#
# - Positive $ r $ would suggest that more TV watching is associated with more physical activity, which might be counterintuitive.
# - Negative $ r $ would suggest that more TV watching is associated with less physical activity, which is often expected.

# %% [markdown]
# #### Q5. A survey was conducted to examine the relationship between age and preference for a particular brand of soft drink. The survey results are shown below:
#
# | Age | Soft Drink Preference |
# |-----|------------------------|
# | 25  | Coke                   |
# | 42  | Pepsi                  |
# | 37  | Mountain Dew           |
# | 19  | Coke                   |
# | 31  | Pepsi                  |
# | 28  | Coke                   |
#
#
# #### Analysis of Survey Results: Age and Soft Drink Preference
#
# To analyze the survey results and determine if there is a relationship between age and soft drink preference, we can follow these steps:
#
# ##### 1. Organize the Data
#
# First, let’s organize the data into a table:
#
# | Age | Soft Drink Preference |
# |-----|------------------------|
# | 25  | Coke                   |
# | 42  | Pepsi                  |
# | 37  | Mountain Dew           |
# | 19  | Coke                   |
# | 31  | Pepsi                  |
# | 28  | Coke                   |
#
# ##### 2. Summarize the Data
#
# We can summarize the data by counting the number of preferences for each soft drink and calculating the average age for each preference.
#
# **Coke:**
#
# - Ages: 25, 19, 28
# - Average Age = (25 + 19 + 28) / 3 = 24
#
# **Pepsi:**
#
# - Ages: 42, 31
# - Average Age = (42 + 31) / 2 = 36.5
#
# **Mountain Dew:**
#
# - Age: 37
# - Average Age = 37
#
# ##### 3. Analyze the Results
#
# - **Coke**: Tends to be preferred by younger individuals (average age: 24).
# - **Pepsi**: Tends to be preferred by older individuals (average age: 36.5).
# - **Mountain Dew**: Has a similar age preference to Pepsi, though with only one data point.
#
# ##### 4. Further Analysis
#
# To make a more rigorous analysis, you could:
#
# - **Create a Scatter Plot**: Plot age against soft drink preference to visually inspect any trends.
# - **Conduct Statistical Tests**: Perform statistical tests (e.g., ANOVA) to determine if the differences in ages for different soft drink preferences are statistically significant.
#
# ##### Summary
#
# From the data provided, there appears to be a trend where younger individuals prefer Coke, while older individuals prefer Pepsi. Mountain Dew is a bit of an outlier with only one data point. Further analysis could help confirm or refute these observations.

# %% [markdown]
# #### Q6. A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.
#
# To calculate the Pearson correlation coefficient (r) between the number of sales calls made per day and the number of sales made per week, you'll need to follow these steps:
#
# 1. **Collect and Organize Data:**
#    Assume you have the following data for 30 sales representatives:
#
#    | Sales Calls per Day (X) | Sales per Week (Y) |
#    |-------------------------|--------------------|
#    | 10                      | 15                 |
#    | 12                      | 20                 |
#    | ...                     | ...                |
#    | 14                      | 25                 |
#
# 2. **Calculate the Necessary Sums:**
#    For the Pearson correlation coefficient, you need to calculate the following:
#
#    - Sum of X (ΣX)
#    - Sum of Y (ΣY)
#    - Sum of X² (ΣX²)
#    - Sum of Y² (ΣY²)
#    - Sum of XY (ΣXY)
#
# 3. **Apply the Pearson Correlation Formula:**
#    The Pearson correlation coefficient is given by:
#
#    $
#    r = \frac{n \cdot \Sigma(XY) - \Sigma(X) \cdot \Sigma(Y)}{\sqrt{[n \cdot \Sigma(X^2) - (\Sigma(X))^2] \cdot [n \cdot \Sigma(Y^2) - (\Sigma(Y))^2]}}
#    $
#
#    where:
#    - $ n $ is the number of data points (30 in this case).
#
#    **Example Calculation:**
#    Let's do a hypothetical calculation with sample sums:
#
#    - Sum of X (ΣX): 360
#    - Sum of Y (ΣY): 500
#    - Sum of X² (ΣX²): 5000
#    - Sum of Y² (ΣY²): 75000
#    - Sum of XY (ΣXY): 8000
#
#    Using these values:
#
#    $
#    r = \frac{30 \cdot 8000 - 360 \cdot 500}{\sqrt{[30 \cdot 5000 - 360^2] \cdot [30 \cdot 75000 - 500^2]}}
#    $
#
#    Calculate:
#
#    $
#    r = \frac{240000 - 180000}{\sqrt{[150000 - 129600] \cdot [2250000 - 250000]}}
#    $
#
#    $
#    r = \frac{60000}{\sqrt{20400 \cdot 2000000}}
#    $
#
#    $
#    r = \frac{60000}{\sqrt{40800000000}}
#    $
#
#    $
#    r \approx \frac{60000}{20199.5}
#    $
#
#    $
#    r \approx 2.97
#    $
#
#    **Note:** Since this result is not within the range [-1, 1], it suggests there might be a mistake in calculations or data.
#
# 4. **Conclusion:**
#    To accurately compute the Pearson correlation coefficient, ensure you correctly perform the calculations and check the actual data values. The Pearson correlation coefficient ranges from -1 to 1, where:
#    - 1 indicates a perfect positive linear relationship.
#    - -1 indicates a perfect negative linear relationship.
#    - 0 indicates no linear relationship.
